# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
file="/Users/lxer/Documents/GitHub/gnn-study/GLNN-v3/outputs/transductive/cora/GCN/seed_0/loss_and_score.npz"
loss_and_score=torch.from_numpy(np.load(file)["arr_0"])

# %%
epoch,loss_train,loss_val,loss_test,score_train,score_val,score_test=(
    loss_and_score[:,0],
    loss_and_score[:,1],
    loss_and_score[:,2],
    loss_and_score[:,3],
    loss_and_score[:,4],
    loss_and_score[:,5],
    loss_and_score[:,6]
)

# %%
plt.plot(epoch,loss_train)

# %%
loss_train
# Out:
# tensor([1.7598, 1.5322, 1.2723, 1.0266, 0.8115, 0.6320, 0.4872, 0.3723, 0.2859,
#         0.2211, 0.1729, 0.1376, 0.1114, 0.0916, 0.0762, 0.0645, 0.0552, 0.0474,
#         0.0409, 0.0357, 0.0315, 0.0284, 0.0263, 0.0250, 0.0240, 0.0222, 0.0201,
#         0.0183, 0.0173, 0.0172, 0.0173, 0.0175, 0.0172, 0.0167, 0.0160, 0.0156,
#         0.0155, 0.0157, 0.0159, 0.0158, 0.0157, 0.0154, 0.0153, 0.0151, 0.0149,
#         0.0149, 0.0151, 0.0154, 0.0158, 0.0163, 0.0168, 0.0170, 0.0166, 0.0160,
#         0.0157, 0.0158, 0.0163, 0.0173, 0.0179, 0.0182, 0.0182, 0.0179, 0.0174,
#         0.0172, 0.0173, 0.0172, 0.0172, 0.0174, 0.0174, 0.0171, 0.0169, 0.0168,
#         0.0163, 0.0159, 0.0156, 0.0156, 0.0155, 0.0152, 0.0148, 0.0144, 0.0141,
#         0.0139, 0.0139, 0.0142, 0.0144, 0.0141, 0.0140, 0.0139, 0.0135, 0.0131,
#         0.0128, 0.0127, 0.0127, 0.0128, 0.0128, 0.0127, 0.0128, 0.0129, 0.0133,
#         0.0135, 0.0136, 0.0136, 0.0134, 0.0130, 0.0126, 0.0125, 0.0127, 0.0129,
# ...

# %%
plt.plot(epoch,loss_val)

# %%
plt.plot(epoch,score_val)
